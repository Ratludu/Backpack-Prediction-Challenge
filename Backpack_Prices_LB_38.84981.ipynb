# %% [markdown]
# <a href="https://colab.research.google.com/github/Ratludu/Backpack-Prediction-Challenge/blob/main/Backpack_Prices_LB_38.84981.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import locale
def getpreferredencoding(do_setlocale = True):
    return "UTF-8"
locale.getpreferredencoding = getpreferredencoding

# %%
from google.colab import userdata
import os
os.environ['KAGGLE_USERNAME'] = userdata.get('kaggleusername')
os.environ['KAGGLE_KEY'] = userdata.get('kaggleapi')

competition = 'playground-series-s5e2'

# !kaggle competitions download -c {competition}

# !unzip "{competition}.zip"
# Out:
# Downloading playground-series-s5e2.zip to /content
#  98% 91.0M/92.7M [00:02<00:00, 43.2MB/s]
# 100% 92.7M/92.7M [00:02<00:00, 33.8MB/s]
# Archive:  playground-series-s5e2.zip
#   inflating: sample_submission.csv
#   inflating: test.csv
#   inflating: train.csv
#   inflating: training_extra.csv

# %%
# !pip install dask-cuda==24.12.0
# Out:
# Collecting dask-cuda==24.12.0
#   Downloading dask_cuda-24.12.0-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: click>=8.1 in /usr/local/lib/python3.11/dist-packages (from dask-cuda==24.12.0) (8.1.8)
# Requirement already satisfied: numba>=0.57 in /usr/local/lib/python3.11/dist-packages (from dask-cuda==24.12.0) (0.61.0)
# Requirement already satisfied: numpy<3.0a0,>=1.23 in /usr/local/lib/python3.11/dist-packages (from dask-cuda==24.12.0) (1.26.4)
# Requirement already satisfied: pandas>=1.3 in /usr/local/lib/python3.11/dist-packages (from dask-cuda==24.12.0) (2.2.2)
# Collecting pynvml<12.0.0a0,>=11.0.0 (from dask-cuda==24.12.0)
#   Downloading pynvml-11.5.3-py3-none-any.whl.metadata (8.8 kB)
# Collecting rapids-dask-dependency==24.12.* (from dask-cuda==24.12.0)
#   Downloading rapids_dask_dependency-24.12.0-py3-none-any.whl.metadata (3.7 kB)
# Collecting zict>=2.0.0 (from dask-cuda==24.12.0)
#   Downloading zict-3.0.0-py2.py3-none-any.whl.metadata (899 bytes)
# Collecting dask==2024.11.2 (from rapids-dask-dependency==24.12.*->dask-cuda==24.12.0)
#   Downloading dask-2024.11.2-py3-none-any.whl.metadata (3.7 kB)
# Collecting distributed==2024.11.2 (from rapids-dask-dependency==24.12.*->dask-cuda==24.12.0)
#   Downloading distributed-2024.11.2-py3-none-any.whl.metadata (3.3 kB)
# Collecting dask-expr==1.1.19 (from rapids-dask-dependency==24.12.*->dask-cuda==24.12.0)
#   Downloading dask_expr-1.1.19-py3-none-any.whl.metadata (2.6 kB)
# Collecting pynvml<12.0.0a0,>=11.0.0 (from dask-cuda==24.12.0)
#   Downloading pynvml-11.4.1-py3-none-any.whl.metadata (7.7 kB)
# Requirement already satisfied: cloudpickle>=3.0.0 in /usr/local/lib/python3.11/dist-packages (from dask==2024.11.2->rapids-dask-dependency==24.12.*->dask-cuda==24.12.0) (3.1.1)
# Requirement already satisfied: fsspec>=2021.09.0 in /usr/local/lib/python3.11/dist-packages (from dask==2024.11.2->rapids-dask-dependency==24.12.*->dask-cuda==24.12.0) (2024.10.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from dask==2024.11.2->rapids-dask-dependency==24.12.*->dask-cuda==24.12.0) (24.2)
# Requirement already satisfied: partd>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from dask==2024.11.2->rapids-dask-dependency==24.12.*->dask-cuda==24.12.0) (1.4.2)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.11/dist-packages (from dask==2024.11.2->rapids-dask-dependency==24.12.*->dask-cuda==24.12.0) (6.0.2)
# Requirement already satisfied: toolz>=0.10.0 in /usr/local/lib/python3.11/dist-packages (from dask==2024.11.2->rapids-dask-dependency==24.12.*->dask-cuda==24.12.0) (0.12.1)
# Requirement already satisfied: importlib-metadata>=4.13.0 in /usr/local/lib/python3.11/dist-packages (from dask==2024.11.2->rapids-dask-dependency==24.12.*->dask-cuda==24.12.0) (8.6.1)
# Requirement already satisfied: pyarrow>=14.0.1 in /usr/local/lib/python3.11/dist-packages (from dask-expr==1.1.19->rapids-dask-dependency==24.12.*->dask-cuda==24.12.0) (17.0.0)
# Requirement already satisfied: jinja2>=2.10.3 in /usr/local/lib/python3.11/dist-packages (from distributed==2024.11.2->rapids-dask-dependency==24.12.*->dask-cuda==24.12.0) (3.1.5)
# Requirement already satisfied: locket>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from distributed==2024.11.2->rapids-dask-dependency==24.12.*->dask-cuda==24.12.0) (1.0.0)
# Requirement already satisfied: msgpack>=1.0.2 in /usr/local/lib/python3.11/dist-packages (from distributed==2024.11.2->rapids-dask-dependency==24.12.*->dask-cuda==24.12.0) (1.1.0)
# Requirement already satisfied: psutil>=5.8.0 in /usr/local/lib/python3.11/dist-packages (from distributed==2024.11.2->rapids-dask-dependency==24.12.*->dask-cuda==24.12.0) (5.9.5)
# Collecting sortedcontainers>=2.0.5 (from distributed==2024.11.2->rapids-dask-dependency==24.12.*->dask-cuda==24.12.0)
#   Downloading sortedcontainers-2.4.0-py2.py3-none-any.whl.metadata (10 kB)
# Collecting tblib>=1.6.0 (from distributed==2024.11.2->rapids-dask-dependency==24.12.*->dask-cuda==24.12.0)
#   Downloading tblib-3.0.0-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: tornado>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from distributed==2024.11.2->rapids-dask-dependency==24.12.*->dask-cuda==24.12.0) (6.4.2)
# Requirement already satisfied: urllib3>=1.26.5 in /usr/local/lib/python3.11/dist-packages (from distributed==2024.11.2->rapids-dask-dependency==24.12.*->dask-cuda==24.12.0) (2.3.0)
# Requirement already satisfied: llvmlite<0.45,>=0.44.0dev0 in /usr/local/lib/python3.11/dist-packages (from numba>=0.57->dask-cuda==24.12.0) (0.44.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.3->dask-cuda==24.12.0) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.3->dask-cuda==24.12.0) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.3->dask-cuda==24.12.0) (2025.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas>=1.3->dask-cuda==24.12.0) (1.17.0)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.11/dist-packages (from importlib-metadata>=4.13.0->dask==2024.11.2->rapids-dask-dependency==24.12.*->dask-cuda==24.12.0) (3.21.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2>=2.10.3->distributed==2024.11.2->rapids-dask-dependency==24.12.*->dask-cuda==24.12.0) (3.0.2)
# Downloading dask_cuda-24.12.0-py3-none-any.whl (134 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.4/134.4 kB 9.6 MB/s eta 0:00:00
# Downloading rapids_dask_dependency-24.12.0-py3-none-any.whl (15 kB)
# Downloading dask-2024.11.2-py3-none-any.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 56.9 MB/s eta 0:00:00
# Downloading dask_expr-1.1.19-py3-none-any.whl (244 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 244.5/244.5 kB 22.9 MB/s eta 0:00:00
# Downloading distributed-2024.11.2-py3-none-any.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 61.7 MB/s eta 0:00:00
# Downloading pynvml-11.4.1-py3-none-any.whl (46 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.0/47.0 kB 4.4 MB/s eta 0:00:00
# Downloading zict-3.0.0-py2.py3-none-any.whl (43 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.3/43.3 kB 3.9 MB/s eta 0:00:00
# Downloading sortedcontainers-2.4.0-py2.py3-none-any.whl (29 kB)
# Downloading tblib-3.0.0-py3-none-any.whl (12 kB)
# Installing collected packages: sortedcontainers, zict, tblib, pynvml, dask, distributed, dask-expr, rapids-dask-dependency, dask-cuda
#   Attempting uninstall: dask
#     Found existing installation: dask 2024.10.0
#     Uninstalling dask-2024.10.0:
#       Successfully uninstalled dask-2024.10.0
# Successfully installed dask-2024.11.2 dask-cuda-24.12.0 dask-expr-1.1.19 distributed-2024.11.2 pynvml-11.4.1 rapids-dask-dependency-24.12.0 sortedcontainers-2.4.0 tblib-3.0.0 zict-3.0.0

# %%
# !git clone https://github.com/rapidsai/rapidsai-csp-utils.git
# !python rapidsai-csp-utils/colab/pip-install.py
# Out:
# Cloning into 'rapidsai-csp-utils'...
# remote: Enumerating objects: 577, done.
# remote: Counting objects: 100% (143/143), done.
# remote: Compressing objects: 100% (61/61), done.
# remote: Total 577 (delta 116), reused 82 (delta 82), pack-reused 434 (from 3)
# Receiving objects: 100% (577/577), 188.95 KiB | 5.40 MiB/s, done.
# Resolving deltas: 100% (290/290), done.
# Installing RAPIDS remaining 24.12.* libraries
# Using Python 3.11.11 environment at /usr
# Resolved 154 packages in 3.21s
# Prepared 21 packages in 49.32s
# Uninstalled 1 package in 120ms
# Installed 21 packages in 106ms
#  + cucim-cu12==24.12.0
#  + cugraph-cu12==24.12.0
#  + cuml-cu12==24.12.0
#  + cuproj-cu12==24.12.0
#  + cuspatial-cu12==24.12.0
#  + cuvs-cu12==24.12.0
#  + cuxfilter-cu12==24.12.0
#  + dask-cudf-cu12==24.12.0
#  + datashader==0.17.0
#  + distributed-ucxx-cu12==0.41.0
#  + jupyter-server-proxy==4.4.0
#  + libcuspatial-cu12==24.12.0
#  + libucx-cu12==1.17.0.post1
#  + libucxx-cu12==0.41.0
#  + pyct==0.5.0
#  + raft-dask-cu12==24.12.0
#  - scikit-image==0.25.1
#  + scikit-image==0.24.0
#  + simpervisor==1.0.0
#  + treelite==4.3.0
#  + ucx-py-cu12==0.41.0
#  + ucxx-cu12==0.41.0
#
#         ***********************************************************************
#         The pip install of RAPIDS is complete.
#
#         Please do not run any further installation from the conda based installation methods, as they may cause issues!
#
#         Please ensure that you're pulling from the git repo to remain updated with the latest working install scripts.
#
#         Troubleshooting:
#             - If there is an installation failure, please check back on RAPIDSAI owned templates/notebooks to see how to update your personal files.
#             - If an installation failure persists when using the latest script, please make an issue on https://github.com/rapidsai-community/rapidsai-csp-utils
#         ***********************************************************************

# %%
# !pip install catboost
# !pip install optuna
# !pip install scikit-learn
# !pip install numpy
# !pip install seaborn
# !pip install matplotlib
# !pip install pandas
# Out:
# Collecting catboost
#   Downloading catboost-1.2.7-cp311-cp311-manylinux2014_x86_64.whl.metadata (1.2 kB)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.11/dist-packages (from catboost) (0.20.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from catboost) (3.10.0)
# Requirement already satisfied: numpy<2.0,>=1.16.0 in /usr/local/lib/python3.11/dist-packages (from catboost) (1.26.4)
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.11/dist-packages (from catboost) (2.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from catboost) (1.13.1)
# Requirement already satisfied: plotly in /usr/local/lib/python3.11/dist-packages (from catboost) (5.24.1)
# Requirement already satisfied: six in /usr/local/lib/python3.11/dist-packages (from catboost) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.24->catboost) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.24->catboost) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.24->catboost) (2025.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (4.55.8)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (3.2.1)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from plotly->catboost) (9.0.0)
# Downloading catboost-1.2.7-cp311-cp311-manylinux2014_x86_64.whl (98.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.7/98.7 MB 8.5 MB/s eta 0:00:00
# Installing collected packages: catboost
# Successfully installed catboost-1.2.7
# Collecting optuna
#   Downloading optuna-4.2.0-py3-none-any.whl.metadata (17 kB)
# Collecting alembic>=1.5.0 (from optuna)
#   Downloading alembic-1.14.1-py3-none-any.whl.metadata (7.4 kB)
# Collecting colorlog (from optuna)
#   Downloading colorlog-6.9.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from optuna) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from optuna) (24.2)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.11/dist-packages (from optuna) (2.0.37)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from optuna) (4.67.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.11/dist-packages (from optuna) (6.0.2)
# Collecting Mako (from alembic>=1.5.0->optuna)
#   Downloading Mako-1.3.9-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: typing-extensions>=4 in /usr/local/lib/python3.11/dist-packages (from alembic>=1.5.0->optuna) (4.12.2)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy>=1.4.2->optuna) (3.1.1)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.11/dist-packages (from Mako->alembic>=1.5.0->optuna) (3.0.2)
# Downloading optuna-4.2.0-py3-none-any.whl (383 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 383.4/383.4 kB 20.0 MB/s eta 0:00:00
# Downloading alembic-1.14.1-py3-none-any.whl (233 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.6/233.6 kB 22.9 MB/s eta 0:00:00
# Downloading colorlog-6.9.0-py3-none-any.whl (11 kB)
# Downloading Mako-1.3.9-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.5/78.5 kB 7.7 MB/s eta 0:00:00
# Installing collected packages: Mako, colorlog, alembic, optuna
# Successfully installed Mako-1.3.9 alembic-1.14.1 colorlog-6.9.0 optuna-4.2.0
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (1.6.1)
# Requirement already satisfied: numpy>=1.19.5 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (1.26.4)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.11/dist-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /usr/local/lib/python3.11/dist-packages (from seaborn) (1.26.4)
# Requirement already satisfied: pandas>=1.2 in /usr/local/lib/python3.11/dist-packages (from seaborn) (2.2.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /usr/local/lib/python3.11/dist-packages (from seaborn) (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.55.8)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.2->seaborn) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.2->seaborn) (2025.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (4.55.8)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.2)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
import pandas as pd
import numpy as np
from numpy import random
from cuml.preprocessing import TargetEncoder
from catboost import CatBoostRegressor
from sklearn.model_selection import cross_validate, cross_val_predict
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
import matplotlib.pyplot as plt
import seaborn as sns
import optuna

# %%
class config:
    # data links
    train_link = "train.csv"
    train_ex_link = "training_extra.csv"
    test_link = "test.csv"
    sub_link = "sample_submission.csv"

    # create folds config

    n_splits = 25

    # Ignore Columns

    col_ignore = ["id", "Price"]
    num_cols = ["Weight Capacity (kg)"]
    # target

    submit = True

    target = "Price"

    add_original = False

# %%
def rmse(y_true, y_pred):
    error = 0

    for yt, yp in zip(y_true, y_pred):
        error += (yt - yp) ** 2

    m = np.sqrt(error / len(y_true))

    return m

# %%
def random_columns(columns):

  # Generate random number for how many columns we want to concat
  rand_num = np.random.randint(2,5)

  # choose the columns from the list of columns with no repeats
  rand_cols = []
  for i in range(rand_num):
    col = np.random.choice(columns)
    while col in rand_cols:
      col = np.random.choice(columns)
    rand_cols.append(col)

  # return a list of the columns

  return "-".join(col for col in rand_cols),rand_cols

# %%
train = pd.read_csv(config.train_link)
train_ex = pd.read_csv(config.train_ex_link)
test = pd.read_csv(config.test_link)

# %%
train = pd.concat([train,train_ex], axis = 0, ignore_index = True)

# %%
kf = KFold(n_splits = config.n_splits, shuffle = True, random_state = 42)

drop = ['Brand', 'Material', 'Size', 'Compartments', 'Laptop Compartment', 'Color', 'Waterproof']
added_fe = ['size-laptop compartment_fe','Color-waterproof_fe','weightcapacity-color_fe']
oof = np.zeros(len(train))
preds = np.zeros(len(test))
features = [col for col in train.columns if col not in config.col_ignore]
cats = [col for col in features if col not in config.num_cols]
cats.extend(added_fe)
m = []
for fold, (train_idx, test_idx) in enumerate(kf.split(train)):

    x_train, x_val = train.loc[train_idx, features].copy(), train.loc[test_idx, features].copy()
    y_train, y_val = train.loc[train_idx, config.target].copy(), train.loc[test_idx, config.target].copy()
    x_test = test[features].copy()

    TE = TargetEncoder(n_folds=27, smooth=21, split_method = 'random', stat = 'mean')


    # adding extra features

    x_train["size-laptop compartment_fe"] = x_train['Size'].astype('str')+x_train['Laptop Compartment'].astype('str')
    x_val["size-laptop compartment_fe"] = x_val['Size'].astype('str')+x_val['Laptop Compartment'].astype('str')
    x_test["size-laptop compartment_fe"] = x_test['Size'].astype('str')+x_test['Laptop Compartment'].astype('str')

    x_train["Color-waterproof_fe"] = x_train['Color'].astype('str')+x_train['Waterproof'].astype('str')
    x_val["Color-waterproof_fe"] = x_val['Color'].astype('str')+x_val['Waterproof'].astype('str')
    x_test["Color-waterproof_fe"] = x_test['Color'].astype('str')+x_test['Waterproof'].astype('str')

    x_train["weightcapacity-color_fe"] = x_train['Weight Capacity (kg)'].astype('str') + x_train['Color'].astype('str')
    x_val["weightcapacity-color_fe"] = x_val['Weight Capacity (kg)'].astype('str') + x_val['Color'].astype('str')
    x_test["weightcapacity-color_fe"] = x_test['Weight Capacity (kg)'].astype('str')+x_test['Color'].astype('str')

    for col in added_fe:
      TE.fit(x_train[col], y_train)
      x_train[f'{col}_TE'] = TE.transform(x_train[col])
      x_val[f'{col}_TE'] = TE.transform(x_val[col])
      x_test[f'{col}_TE'] = TE.transform(x_test[col])

    for col in features:
        TE.fit(x_train[col], y_train)
        x_train[f'{col}_TE'] = TE.transform(x_train[col])
        x_val[f'{col}_TE'] = TE.transform(x_val[col])
        x_test[f'{col}_TE'] = TE.transform(x_test[col])

    x_train["colorxweight"] = x_train['Color_TE']*x_train['Weight Capacity (kg)_TE']
    x_val["colorxweight"] = x_val['Color_TE']*x_val['Weight Capacity (kg)_TE']
    x_test["colorxweight"] = x_test['Color_TE']*x_test['Weight Capacity (kg)_TE']

    x_train["Sizexweight"] = x_train['Size_TE']*x_train['Weight Capacity (kg)_TE']
    x_val["Sizexweight"] = x_val['Size_TE']*x_val['Weight Capacity (kg)_TE']
    x_test["Sizexweight"] = x_test['Size_TE']*x_test['Weight Capacity (kg)_TE']

    x_train["Sizexbrand"] = x_train['Size_TE']*x_train['Brand_TE']
    x_val["Sizexbrand"] = x_val['Size_TE']*x_val['Brand_TE']
    x_test["Sizexbrand"] = x_test['Size_TE']*x_test['Brand_TE']

    x_train["Materialxweight"] = x_train['Material_TE']*x_train['Weight Capacity (kg)_TE']
    x_val["Materialxweight"] = x_val['Material_TE']*x_val['Weight Capacity (kg)_TE']
    x_test["Materialxweight"] = x_test['Material_TE']*x_test['Weight Capacity (kg)_TE']

    for cat in cats:
        x_train[cat] =  x_train[cat].fillna("MISSING")
        x_val[cat] = x_val[cat].fillna("MISSING")
        x_test[cat] = x_test[cat].fillna("MISSING")
        x_train[cat] =  x_train[cat].astype('str')
        x_val[cat] = x_val[cat].astype('str')
        x_test[cat] = x_test[cat].astype('str')

    print(x_train.columns)

    model = CatBoostRegressor(task_type = "GPU",
                              grow_policy = 'Lossguide',
                              random_state = 42,
                              cat_features = cats,
                              verbose = 250,
                              loss_function='RMSE')

    model.fit(x_train, y_train)

    val_preds = model.predict(x_val)

    oof[test_idx] = val_preds

    preds += model.predict(x_test)/config.n_splits

    score = rmse(y_val, val_preds)

    m.append(score)

    print(f'Fold: {fold+1}, Score: {score}')

print(f"The average CV is {np.average(m)}")
# Out:
# Index(['Brand', 'Material', 'Size', 'Compartments', 'Laptop Compartment',
#        'Waterproof', 'Style', 'Color', 'Weight Capacity (kg)',
#        'size-laptop compartment_fe', 'Color-waterproof_fe',
#        'weightcapacity-color_fe', 'size-laptop compartment_fe_TE',
#        'Color-waterproof_fe_TE', 'weightcapacity-color_fe_TE', 'Brand_TE',
#        'Material_TE', 'Size_TE', 'Compartments_TE', 'Laptop Compartment_TE',
#        'Waterproof_TE', 'Style_TE', 'Color_TE', 'Weight Capacity (kg)_TE',
#        'colorxweight', 'Sizexweight', 'Sizexbrand', 'Materialxweight'],
#       dtype='object')
# Learning rate set to 0.119064
# 0:	learn: 38.8853615	total: 223ms	remaining: 3m 42s
# 250:	learn: 38.6229731	total: 15.7s	remaining: 46.7s
# 500:	learn: 38.5940368	total: 28.1s	remaining: 28s
# 750:	learn: 38.5681082	total: 41.9s	remaining: 13.9s
# 999:	learn: 38.5447776	total: 56.5s	remaining: 0us
# Fold: 1, Score: 38.63887487293114
# Index(['Brand', 'Material', 'Size', 'Compartments', 'Laptop Compartment',
#        'Waterproof', 'Style', 'Color', 'Weight Capacity (kg)',
#        'size-laptop compartment_fe', 'Color-waterproof_fe',
#        'weightcapacity-color_fe', 'size-laptop compartment_fe_TE',
#        'Color-waterproof_fe_TE', 'weightcapacity-color_fe_TE', 'Brand_TE',
#        'Material_TE', 'Size_TE', 'Compartments_TE', 'Laptop Compartment_TE',
#        'Waterproof_TE', 'Style_TE', 'Color_TE', 'Weight Capacity (kg)_TE',
#        'colorxweight', 'Sizexweight', 'Sizexbrand', 'Materialxweight'],
#       dtype='object')
# Learning rate set to 0.119064
# 0:	learn: 38.8836669	total: 129ms	remaining: 2m 8s
# 250:	learn: 38.6201658	total: 18.3s	remaining: 54.6s
# 500:	learn: 38.5914177	total: 32.9s	remaining: 32.8s
# 750:	learn: 38.5663304	total: 47.3s	remaining: 15.7s
# 999:	learn: 38.5428740	total: 1m 1s	remaining: 0us
# Fold: 2, Score: 38.67897148631351
# Index(['Brand', 'Material', 'Size', 'Compartments', 'Laptop Compartment',
#        'Waterproof', 'Style', 'Color', 'Weight Capacity (kg)',
#        'size-laptop compartment_fe', 'Color-waterproof_fe',
#        'weightcapacity-color_fe', 'size-laptop compartment_fe_TE',
#        'Color-waterproof_fe_TE', 'weightcapacity-color_fe_TE', 'Brand_TE',
#        'Material_TE', 'Size_TE', 'Compartments_TE', 'Laptop Compartment_TE',
#        'Waterproof_TE', 'Style_TE', 'Color_TE', 'Weight Capacity (kg)_TE',
#        'colorxweight', 'Sizexweight', 'Sizexbrand', 'Materialxweight'],
#       dtype='object')
# Learning rate set to 0.119064
# 0:	learn: 38.8868363	total: 84.3ms	remaining: 1m 24s
# 250:	learn: 38.6241692	total: 15.8s	remaining: 47s
# 500:	learn: 38.5971798	total: 30.4s	remaining: 30.3s
# 750:	learn: 38.5711390	total: 46.4s	remaining: 15.4s
# 999:	learn: 38.5479558	total: 1m 3s	remaining: 0us
# Fold: 3, Score: 38.61477263305763
# Index(['Brand', 'Material', 'Size', 'Compartments', 'Laptop Compartment',
#        'Waterproof', 'Style', 'Color', 'Weight Capacity (kg)',
#        'size-laptop compartment_fe', 'Color-waterproof_fe',
#        'weightcapacity-color_fe', 'size-laptop compartment_fe_TE',
#        'Color-waterproof_fe_TE', 'weightcapacity-color_fe_TE', 'Brand_TE',
#        'Material_TE', 'Size_TE', 'Compartments_TE', 'Laptop Compartment_TE',
#        'Waterproof_TE', 'Style_TE', 'Color_TE', 'Weight Capacity (kg)_TE',
#        'colorxweight', 'Sizexweight', 'Sizexbrand', 'Materialxweight'],
#       dtype='object')
# Learning rate set to 0.119064
# 0:	learn: 38.8854268	total: 83.9ms	remaining: 1m 23s
# 250:	learn: 38.6212549	total: 15.8s	remaining: 47s
# 500:	learn: 38.5920076	total: 30.5s	remaining: 30.4s
# 750:	learn: 38.5675214	total: 44s	remaining: 14.6s
# 999:	learn: 38.5437158	total: 55.3s	remaining: 0us
# Fold: 4, Score: 38.62971387384352
# Index(['Brand', 'Material', 'Size', 'Compartments', 'Laptop Compartment',
#        'Waterproof', 'Style', 'Color', 'Weight Capacity (kg)',
#        'size-laptop compartment_fe', 'Color-waterproof_fe',
#        'weightcapacity-color_fe', 'size-laptop compartment_fe_TE',
#        'Color-waterproof_fe_TE', 'weightcapacity-color_fe_TE', 'Brand_TE',
#        'Material_TE', 'Size_TE', 'Compartments_TE', 'Laptop Compartment_TE',
#        'Waterproof_TE', 'Style_TE', 'Color_TE', 'Weight Capacity (kg)_TE',
#        'colorxweight', 'Sizexweight', 'Sizexbrand', 'Materialxweight'],
#       dtype='object')
# Learning rate set to 0.119064
# 0:	learn: 38.8864758	total: 82.8ms	remaining: 1m 22s
# 250:	learn: 38.6234363	total: 15.4s	remaining: 46.1s
# 500:	learn: 38.5953480	total: 30.1s	remaining: 30s
# 750:	learn: 38.5692714	total: 44.7s	remaining: 14.8s
# 999:	learn: 38.5457077	total: 58.8s	remaining: 0us
# Fold: 5, Score: 38.60811057184719
# Index(['Brand', 'Material', 'Size', 'Compartments', 'Laptop Compartment',
#        'Waterproof', 'Style', 'Color', 'Weight Capacity (kg)',
#        'size-laptop compartment_fe', 'Color-waterproof_fe',
#        'weightcapacity-color_fe', 'size-laptop compartment_fe_TE',
#        'Color-waterproof_fe_TE', 'weightcapacity-color_fe_TE', 'Brand_TE',
#        'Material_TE', 'Size_TE', 'Compartments_TE', 'Laptop Compartment_TE',
#        'Waterproof_TE', 'Style_TE', 'Color_TE', 'Weight Capacity (kg)_TE',
#        'colorxweight', 'Sizexweight', 'Sizexbrand', 'Materialxweight'],
#       dtype='object')
# Learning rate set to 0.119064
# 0:	learn: 38.8886732	total: 83.3ms	remaining: 1m 23s
# 250:	learn: 38.6264283	total: 23.3s	remaining: 1m 9s
# 500:	learn: 38.5979132	total: 36.7s	remaining: 36.6s
# 750:	learn: 38.5736574	total: 48.3s	remaining: 16s
# 999:	learn: 38.5505033	total: 1m 2s	remaining: 0us
# Fold: 6, Score: 38.57681012060984
# Index(['Brand', 'Material', 'Size', 'Compartments', 'Laptop Compartment',
#        'Waterproof', 'Style', 'Color', 'Weight Capacity (kg)',
#        'size-laptop compartment_fe', 'Color-waterproof_fe',
#        'weightcapacity-color_fe', 'size-laptop compartment_fe_TE',
#        'Color-waterproof_fe_TE', 'weightcapacity-color_fe_TE', 'Brand_TE',
#        'Material_TE', 'Size_TE', 'Compartments_TE', 'Laptop Compartment_TE',
#        'Waterproof_TE', 'Style_TE', 'Color_TE', 'Weight Capacity (kg)_TE',
#        'colorxweight', 'Sizexweight', 'Sizexbrand', 'Materialxweight'],
#       dtype='object')
# Learning rate set to 0.119064
# 0:	learn: 38.8861839	total: 85.2ms	remaining: 1m 25s
# 250:	learn: 38.6218270	total: 16s	remaining: 47.8s
# 500:	learn: 38.5934867	total: 30.9s	remaining: 30.8s
# 750:	learn: 38.5677083	total: 45.3s	remaining: 15s
# 999:	learn: 38.5433209	total: 1m 3s	remaining: 0us
# Fold: 7, Score: 38.632159532881495
# Index(['Brand', 'Material', 'Size', 'Compartments', 'Laptop Compartment',
#        'Waterproof', 'Style', 'Color', 'Weight Capacity (kg)',
#        'size-laptop compartment_fe', 'Color-waterproof_fe',
#        'weightcapacity-color_fe', 'size-laptop compartment_fe_TE',
#        'Color-waterproof_fe_TE', 'weightcapacity-color_fe_TE', 'Brand_TE',
#        'Material_TE', 'Size_TE', 'Compartments_TE', 'Laptop Compartment_TE',
#        'Waterproof_TE', 'Style_TE', 'Color_TE', 'Weight Capacity (kg)_TE',
#        'colorxweight', 'Sizexweight', 'Sizexbrand', 'Materialxweight'],
#       dtype='object')
# Learning rate set to 0.119064
# 0:	learn: 38.8830282	total: 135ms	remaining: 2m 14s
# 250:	learn: 38.6207363	total: 16.3s	remaining: 48.7s
# 500:	learn: 38.5929556	total: 29.5s	remaining: 29.3s
# 750:	learn: 38.5666368	total: 43.9s	remaining: 14.6s
# 999:	learn: 38.5428948	total: 58.3s	remaining: 0us
# Fold: 8, Score: 38.69939958644337
# Index(['Brand', 'Material', 'Size', 'Compartments', 'Laptop Compartment',
#        'Waterproof', 'Style', 'Color', 'Weight Capacity (kg)',
#        'size-laptop compartment_fe', 'Color-waterproof_fe',
#        'weightcapacity-color_fe', 'size-laptop compartment_fe_TE',
#        'Color-waterproof_fe_TE', 'weightcapacity-color_fe_TE', 'Brand_TE',
#        'Material_TE', 'Size_TE', 'Compartments_TE', 'Laptop Compartment_TE',
#        'Waterproof_TE', 'Style_TE', 'Color_TE', 'Weight Capacity (kg)_TE',
#        'colorxweight', 'Sizexweight', 'Sizexbrand', 'Materialxweight'],
#       dtype='object')
# Learning rate set to 0.119064
# 0:	learn: 38.8858783	total: 82.1ms	remaining: 1m 22s
# 250:	learn: 38.6234554	total: 15.9s	remaining: 47.3s
# 500:	learn: 38.5941129	total: 30.7s	remaining: 30.5s
# 750:	learn: 38.5686361	total: 43.8s	remaining: 14.5s
# 999:	learn: 38.5451985	total: 56s	remaining: 0us
# Fold: 9, Score: 38.63235165447304
# Index(['Brand', 'Material', 'Size', 'Compartments', 'Laptop Compartment',
#        'Waterproof', 'Style', 'Color', 'Weight Capacity (kg)',
#        'size-laptop compartment_fe', 'Color-waterproof_fe',
#        'weightcapacity-color_fe', 'size-laptop compartment_fe_TE',
#        'Color-waterproof_fe_TE', 'weightcapacity-color_fe_TE', 'Brand_TE',
#        'Material_TE', 'Size_TE', 'Compartments_TE', 'Laptop Compartment_TE',
#        'Waterproof_TE', 'Style_TE', 'Color_TE', 'Weight Capacity (kg)_TE',
#        'colorxweight', 'Sizexweight', 'Sizexbrand', 'Materialxweight'],
#       dtype='object')
# Learning rate set to 0.119064
# 0:	learn: 38.8866766	total: 83.8ms	remaining: 1m 23s
# 250:	learn: 38.6238062	total: 20s	remaining: 59.6s
# 500:	learn: 38.5963132	total: 34.5s	remaining: 34.4s
# 750:	learn: 38.5721273	total: 49.1s	remaining: 16.3s
# 999:	learn: 38.5483628	total: 1m 2s	remaining: 0us
# Fold: 10, Score: 38.59741338164415
# Index(['Brand', 'Material', 'Size', 'Compartments', 'Laptop Compartment',
#        'Waterproof', 'Style', 'Color', 'Weight Capacity (kg)',
#        'size-laptop compartment_fe', 'Color-waterproof_fe',
#        'weightcapacity-color_fe', 'size-laptop compartment_fe_TE',
#        'Color-waterproof_fe_TE', 'weightcapacity-color_fe_TE', 'Brand_TE',
#        'Material_TE', 'Size_TE', 'Compartments_TE', 'Laptop Compartment_TE',
#        'Waterproof_TE', 'Style_TE', 'Color_TE', 'Weight Capacity (kg)_TE',
#        'colorxweight', 'Sizexweight', 'Sizexbrand', 'Materialxweight'],
#       dtype='object')
# Learning rate set to 0.119064
# 0:	learn: 38.8850473	total: 184ms	remaining: 3m 3s
# 250:	learn: 38.6228279	total: 16.5s	remaining: 49.2s
# 500:	learn: 38.5951491	total: 30.5s	remaining: 30.4s
# 750:	learn: 38.5702788	total: 45s	remaining: 14.9s
# 999:	learn: 38.5454479	total: 1m 2s	remaining: 0us
# Fold: 11, Score: 38.6478211257863
# Index(['Brand', 'Material', 'Size', 'Compartments', 'Laptop Compartment',
#        'Waterproof', 'Style', 'Color', 'Weight Capacity (kg)',
#        'size-laptop compartment_fe', 'Color-waterproof_fe',
#        'weightcapacity-color_fe', 'size-laptop compartment_fe_TE',
#        'Color-waterproof_fe_TE', 'weightcapacity-color_fe_TE', 'Brand_TE',
#        'Material_TE', 'Size_TE', 'Compartments_TE', 'Laptop Compartment_TE',
#        'Waterproof_TE', 'Style_TE', 'Color_TE', 'Weight Capacity (kg)_TE',
#        'colorxweight', 'Sizexweight', 'Sizexbrand', 'Materialxweight'],
#       dtype='object')
# Learning rate set to 0.119064
# 0:	learn: 38.8844670	total: 83.9ms	remaining: 1m 23s
# 250:	learn: 38.6217838	total: 16.2s	remaining: 48.3s
# 500:	learn: 38.5946820	total: 31s	remaining: 30.9s
# 750:	learn: 38.5703549	total: 45.4s	remaining: 15.1s
# 999:	learn: 38.5469651	total: 58.8s	remaining: 0us
# Fold: 12, Score: 38.66541488553558
# Index(['Brand', 'Material', 'Size', 'Compartments', 'Laptop Compartment',
#        'Waterproof', 'Style', 'Color', 'Weight Capacity (kg)',
#        'size-laptop compartment_fe', 'Color-waterproof_fe',
#        'weightcapacity-color_fe', 'size-laptop compartment_fe_TE',
#        'Color-waterproof_fe_TE', 'weightcapacity-color_fe_TE', 'Brand_TE',
#        'Material_TE', 'Size_TE', 'Compartments_TE', 'Laptop Compartment_TE',
#        'Waterproof_TE', 'Style_TE', 'Color_TE', 'Weight Capacity (kg)_TE',
#        'colorxweight', 'Sizexweight', 'Sizexbrand', 'Materialxweight'],
#       dtype='object')
# Learning rate set to 0.119064
# 0:	learn: 38.8837202	total: 102ms	remaining: 1m 41s
# 250:	learn: 38.6225064	total: 15.1s	remaining: 45.1s
# 500:	learn: 38.5916945	total: 29.8s	remaining: 29.7s
# 750:	learn: 38.5660430	total: 44.3s	remaining: 14.7s
# 999:	learn: 38.5423111	total: 58.8s	remaining: 0us
# Fold: 13, Score: 38.67320233294714
# Index(['Brand', 'Material', 'Size', 'Compartments', 'Laptop Compartment',
#        'Waterproof', 'Style', 'Color', 'Weight Capacity (kg)',
#        'size-laptop compartment_fe', 'Color-waterproof_fe',
#        'weightcapacity-color_fe', 'size-laptop compartment_fe_TE',
#        'Color-waterproof_fe_TE', 'weightcapacity-color_fe_TE', 'Brand_TE',
#        'Material_TE', 'Size_TE', 'Compartments_TE', 'Laptop Compartment_TE',
#        'Waterproof_TE', 'Style_TE', 'Color_TE', 'Weight Capacity (kg)_TE',
#        'colorxweight', 'Sizexweight', 'Sizexbrand', 'Materialxweight'],
#       dtype='object')
# Learning rate set to 0.119064
# 0:	learn: 38.8822848	total: 219ms	remaining: 3m 38s
# 250:	learn: 38.6193274	total: 15.6s	remaining: 46.5s
# 500:	learn: 38.5919108	total: 29.9s	remaining: 29.8s
# 750:	learn: 38.5667043	total: 44.3s	remaining: 14.7s
# 999:	learn: 38.5426869	total: 58.8s	remaining: 0us
# Fold: 14, Score: 38.71345116157059
# Index(['Brand', 'Material', 'Size', 'Compartments', 'Laptop Compartment',
#        'Waterproof', 'Style', 'Color', 'Weight Capacity (kg)',
#        'size-laptop compartment_fe', 'Color-waterproof_fe',
#        'weightcapacity-color_fe', 'size-laptop compartment_fe_TE',
#        'Color-waterproof_fe_TE', 'weightcapacity-color_fe_TE', 'Brand_TE',
#        'Material_TE', 'Size_TE', 'Compartments_TE', 'Laptop Compartment_TE',
#        'Waterproof_TE', 'Style_TE', 'Color_TE', 'Weight Capacity (kg)_TE',
#        'colorxweight', 'Sizexweight', 'Sizexbrand', 'Materialxweight'],
#       dtype='object')
# Learning rate set to 0.119064
# 0:	learn: 38.8798431	total: 83.9ms	remaining: 1m 23s
# 250:	learn: 38.6164905	total: 15.9s	remaining: 47.5s
# 500:	learn: 38.5877466	total: 28.5s	remaining: 28.4s
# 750:	learn: 38.5627555	total: 41.2s	remaining: 13.7s
# 999:	learn: 38.5396123	total: 55.9s	remaining: 0us
# Fold: 15, Score: 38.76854656156648
# Index(['Brand', 'Material', 'Size', 'Compartments', 'Laptop Compartment',
#        'Waterproof', 'Style', 'Color', 'Weight Capacity (kg)',
#        'size-laptop compartment_fe', 'Color-waterproof_fe',
#        'weightcapacity-color_fe', 'size-laptop compartment_fe_TE',
#        'Color-waterproof_fe_TE', 'weightcapacity-color_fe_TE', 'Brand_TE',
#        'Material_TE', 'Size_TE', 'Compartments_TE', 'Laptop Compartment_TE',
#        'Waterproof_TE', 'Style_TE', 'Color_TE', 'Weight Capacity (kg)_TE',
#        'colorxweight', 'Sizexweight', 'Sizexbrand', 'Materialxweight'],
#       dtype='object')
# Learning rate set to 0.119064
# 0:	learn: 38.8838421	total: 83.7ms	remaining: 1m 23s
# 250:	learn: 38.6213430	total: 15.9s	remaining: 47.6s
# 500:	learn: 38.5925508	total: 30.8s	remaining: 30.7s
# 750:	learn: 38.5663200	total: 45.1s	remaining: 15s
# 999:	learn: 38.5435807	total: 59.7s	remaining: 0us
# Fold: 16, Score: 38.67701532966837
# Index(['Brand', 'Material', 'Size', 'Compartments', 'Laptop Compartment',
#        'Waterproof', 'Style', 'Color', 'Weight Capacity (kg)',
#        'size-laptop compartment_fe', 'Color-waterproof_fe',
#        'weightcapacity-color_fe', 'size-laptop compartment_fe_TE',
#        'Color-waterproof_fe_TE', 'weightcapacity-color_fe_TE', 'Brand_TE',
#        'Material_TE', 'Size_TE', 'Compartments_TE', 'Laptop Compartment_TE',
#        'Waterproof_TE', 'Style_TE', 'Color_TE', 'Weight Capacity (kg)_TE',
#        'colorxweight', 'Sizexweight', 'Sizexbrand', 'Materialxweight'],
#       dtype='object')
# Learning rate set to 0.119064
# 0:	learn: 38.8846233	total: 231ms	remaining: 3m 50s
# 250:	learn: 38.6203836	total: 16.2s	remaining: 48.3s
# 500:	learn: 38.5916444	total: 30s	remaining: 29.9s
# 750:	learn: 38.5653367	total: 44.6s	remaining: 14.8s
# 999:	learn: 38.5407278	total: 59.2s	remaining: 0us
# Fold: 17, Score: 38.654979821263105
# Index(['Brand', 'Material', 'Size', 'Compartments', 'Laptop Compartment',
#        'Waterproof', 'Style', 'Color', 'Weight Capacity (kg)',
#        'size-laptop compartment_fe', 'Color-waterproof_fe',
#        'weightcapacity-color_fe', 'size-laptop compartment_fe_TE',
#        'Color-waterproof_fe_TE', 'weightcapacity-color_fe_TE', 'Brand_TE',
#        'Material_TE', 'Size_TE', 'Compartments_TE', 'Laptop Compartment_TE',
#        'Waterproof_TE', 'Style_TE', 'Color_TE', 'Weight Capacity (kg)_TE',
#        'colorxweight', 'Sizexweight', 'Sizexbrand', 'Materialxweight'],
#       dtype='object')
# Learning rate set to 0.119064
# 0:	learn: 38.8857341	total: 93.2ms	remaining: 1m 33s
# 250:	learn: 38.6227501	total: 16s	remaining: 47.6s
# 500:	learn: 38.5938811	total: 30.8s	remaining: 30.7s
# 750:	learn: 38.5681064	total: 47.3s	remaining: 15.7s
# 999:	learn: 38.5445351	total: 59.1s	remaining: 0us
# Fold: 18, Score: 38.63120676257036
# Index(['Brand', 'Material', 'Size', 'Compartments', 'Laptop Compartment',
#        'Waterproof', 'Style', 'Color', 'Weight Capacity (kg)',
#        'size-laptop compartment_fe', 'Color-waterproof_fe',
#        'weightcapacity-color_fe', 'size-laptop compartment_fe_TE',
#        'Color-waterproof_fe_TE', 'weightcapacity-color_fe_TE', 'Brand_TE',
#        'Material_TE', 'Size_TE', 'Compartments_TE', 'Laptop Compartment_TE',
#        'Waterproof_TE', 'Style_TE', 'Color_TE', 'Weight Capacity (kg)_TE',
#        'colorxweight', 'Sizexweight', 'Sizexbrand', 'Materialxweight'],
#       dtype='object')
# Learning rate set to 0.119064
# 0:	learn: 38.8874270	total: 87.2ms	remaining: 1m 27s
# 250:	learn: 38.6243733	total: 16.1s	remaining: 48.1s
# 500:	learn: 38.5961784	total: 30.8s	remaining: 30.7s
# 750:	learn: 38.5719787	total: 45.3s	remaining: 15s
# 999:	learn: 38.5473775	total: 59.8s	remaining: 0us
# Fold: 19, Score: 38.59523574973466
# Index(['Brand', 'Material', 'Size', 'Compartments', 'Laptop Compartment',
#        'Waterproof', 'Style', 'Color', 'Weight Capacity (kg)',
#        'size-laptop compartment_fe', 'Color-waterproof_fe',
#        'weightcapacity-color_fe', 'size-laptop compartment_fe_TE',
#        'Color-waterproof_fe_TE', 'weightcapacity-color_fe_TE', 'Brand_TE',
#        'Material_TE', 'Size_TE', 'Compartments_TE', 'Laptop Compartment_TE',
#        'Waterproof_TE', 'Style_TE', 'Color_TE', 'Weight Capacity (kg)_TE',
#        'colorxweight', 'Sizexweight', 'Sizexbrand', 'Materialxweight'],
#       dtype='object')
# Learning rate set to 0.119064
# 0:	learn: 38.8854629	total: 147ms	remaining: 2m 27s
# 250:	learn: 38.6225117	total: 15.9s	remaining: 47.4s
# 500:	learn: 38.5921099	total: 28.3s	remaining: 28.2s
# 750:	learn: 38.5662301	total: 41.7s	remaining: 13.8s
# 999:	learn: 38.5410086	total: 55.9s	remaining: 0us
# Fold: 20, Score: 38.643113310762466
# Index(['Brand', 'Material', 'Size', 'Compartments', 'Laptop Compartment',
#        'Waterproof', 'Style', 'Color', 'Weight Capacity (kg)',
#        'size-laptop compartment_fe', 'Color-waterproof_fe',
#        'weightcapacity-color_fe', 'size-laptop compartment_fe_TE',
#        'Color-waterproof_fe_TE', 'weightcapacity-color_fe_TE', 'Brand_TE',
#        'Material_TE', 'Size_TE', 'Compartments_TE', 'Laptop Compartment_TE',
#        'Waterproof_TE', 'Style_TE', 'Color_TE', 'Weight Capacity (kg)_TE',
#        'colorxweight', 'Sizexweight', 'Sizexbrand', 'Materialxweight'],
#       dtype='object')
# Learning rate set to 0.119064
# 0:	learn: 38.8864552	total: 82ms	remaining: 1m 21s
# 250:	learn: 38.6251235	total: 16s	remaining: 47.9s
# 500:	learn: 38.5966766	total: 30.8s	remaining: 30.7s
# 750:	learn: 38.5718696	total: 45.5s	remaining: 15.1s
# 999:	learn: 38.5477481	total: 57.4s	remaining: 0us
# Fold: 21, Score: 38.58908851309309
# Index(['Brand', 'Material', 'Size', 'Compartments', 'Laptop Compartment',
#        'Waterproof', 'Style', 'Color', 'Weight Capacity (kg)',
#        'size-laptop compartment_fe', 'Color-waterproof_fe',
#        'weightcapacity-color_fe', 'size-laptop compartment_fe_TE',
#        'Color-waterproof_fe_TE', 'weightcapacity-color_fe_TE', 'Brand_TE',
#        'Material_TE', 'Size_TE', 'Compartments_TE', 'Laptop Compartment_TE',
#        'Waterproof_TE', 'Style_TE', 'Color_TE', 'Weight Capacity (kg)_TE',
#        'colorxweight', 'Sizexweight', 'Sizexbrand', 'Materialxweight'],
#       dtype='object')
# Learning rate set to 0.119064
# 0:	learn: 38.8828188	total: 85.2ms	remaining: 1m 25s
# 250:	learn: 38.6209663	total: 15.4s	remaining: 46.1s
# 500:	learn: 38.5918037	total: 30s	remaining: 29.9s
# 750:	learn: 38.5670351	total: 48.4s	remaining: 16s
# 999:	learn: 38.5425866	total: 1m 2s	remaining: 0us
# Fold: 22, Score: 38.710904041509075
# Index(['Brand', 'Material', 'Size', 'Compartments', 'Laptop Compartment',
#        'Waterproof', 'Style', 'Color', 'Weight Capacity (kg)',
#        'size-laptop compartment_fe', 'Color-waterproof_fe',
#        'weightcapacity-color_fe', 'size-laptop compartment_fe_TE',
#        'Color-waterproof_fe_TE', 'weightcapacity-color_fe_TE', 'Brand_TE',
#        'Material_TE', 'Size_TE', 'Compartments_TE', 'Laptop Compartment_TE',
#        'Waterproof_TE', 'Style_TE', 'Color_TE', 'Weight Capacity (kg)_TE',
#        'colorxweight', 'Sizexweight', 'Sizexbrand', 'Materialxweight'],
#       dtype='object')
# Learning rate set to 0.119064
# 0:	learn: 38.8818539	total: 87.1ms	remaining: 1m 26s
# 250:	learn: 38.6192031	total: 16s	remaining: 47.8s
# 500:	learn: 38.5905529	total: 29.7s	remaining: 29.6s
# 750:	learn: 38.5655931	total: 41.7s	remaining: 13.8s
# 999:	learn: 38.5421640	total: 55.8s	remaining: 0us
# Fold: 23, Score: 38.713105672574244
# Index(['Brand', 'Material', 'Size', 'Compartments', 'Laptop Compartment',
#        'Waterproof', 'Style', 'Color', 'Weight Capacity (kg)',
#        'size-laptop compartment_fe', 'Color-waterproof_fe',
#        'weightcapacity-color_fe', 'size-laptop compartment_fe_TE',
#        'Color-waterproof_fe_TE', 'weightcapacity-color_fe_TE', 'Brand_TE',
#        'Material_TE', 'Size_TE', 'Compartments_TE', 'Laptop Compartment_TE',
#        'Waterproof_TE', 'Style_TE', 'Color_TE', 'Weight Capacity (kg)_TE',
#        'colorxweight', 'Sizexweight', 'Sizexbrand', 'Materialxweight'],
#       dtype='object')
# Learning rate set to 0.119064
# 0:	learn: 38.8849478	total: 87ms	remaining: 1m 26s
# 250:	learn: 38.6235990	total: 15.8s	remaining: 47.2s
# 500:	learn: 38.5944625	total: 30.3s	remaining: 30.2s
# 750:	learn: 38.5689842	total: 44.4s	remaining: 14.7s
# 999:	learn: 38.5453978	total: 58.4s	remaining: 0us
# Fold: 24, Score: 38.64926881768692
# Index(['Brand', 'Material', 'Size', 'Compartments', 'Laptop Compartment',
#        'Waterproof', 'Style', 'Color', 'Weight Capacity (kg)',
#        'size-laptop compartment_fe', 'Color-waterproof_fe',
#        'weightcapacity-color_fe', 'size-laptop compartment_fe_TE',
#        'Color-waterproof_fe_TE', 'weightcapacity-color_fe_TE', 'Brand_TE',
#        'Material_TE', 'Size_TE', 'Compartments_TE', 'Laptop Compartment_TE',
#        'Waterproof_TE', 'Style_TE', 'Color_TE', 'Weight Capacity (kg)_TE',
#        'colorxweight', 'Sizexweight', 'Sizexbrand', 'Materialxweight'],
#       dtype='object')
# Learning rate set to 0.119064
# 0:	learn: 38.8800578	total: 82.8ms	remaining: 1m 22s
# 250:	learn: 38.6175504	total: 23s	remaining: 1m 8s
# 500:	learn: 38.5886377	total: 36.5s	remaining: 36.4s
# 750:	learn: 38.5632197	total: 48.5s	remaining: 16.1s
# 999:	learn: 38.5397025	total: 1m 2s	remaining: 0us
# Fold: 25, Score: 38.744886266500636
# The average CV is 38.65543272267256

# %%
save_columns ={}
save_score = {}

added_fe = ['size-laptop compartment_fe','Color-waterproof_fe']
for trial in range(10):

  features = [col for col in train.columns if col not in config.col_ignore]
  cats = [col for col in features if col not in config.num_cols]
  cats.extend(added_fe)

  randf,randc = random_columns(features)

  print(f"Trial {trial +1}: {randc}")

  kf = KFold(n_splits = 5, shuffle = True, random_state = 42)

  oof = np.zeros(len(train))
  preds = np.zeros(len(test))
  cats.append(randf)
  m = []
  for fold, (train_idx, test_idx) in enumerate(kf.split(train)):

      x_train, x_val = train.loc[train_idx, features].copy(), train.loc[test_idx, features].copy()
      y_train, y_val = train.loc[train_idx, config.target].copy(), train.loc[test_idx, config.target].copy()
      x_test = test[features].copy()

      TE = TargetEncoder(n_folds=27, smooth=21, split_method = 'random', stat = 'mean')


      # adding extra features

      x_train["size-laptop compartment_fe"] = x_train['Size'].astype('str')+x_train['Laptop Compartment'].astype('str')
      x_val["size-laptop compartment_fe"] = x_val['Size'].astype('str')+x_val['Laptop Compartment'].astype('str')
      x_test["size-laptop compartment_fe"] = x_test['Size'].astype('str')+x_test['Laptop Compartment'].astype('str')

      x_train["Color-waterproof_fe"] = x_train['Color'].astype('str')+x_train['Waterproof'].astype('str')
      x_val["Color-waterproof_fe"] = x_val['Color'].astype('str')+x_val['Waterproof'].astype('str')
      x_test["Color-waterproof_fe"] = x_test['Color'].astype('str')+x_test['Waterproof'].astype('str')

      for col in added_fe:
        TE.fit(x_train[col], y_train)
        x_train[f'{col}_TE'] = TE.transform(x_train[col])
        x_val[f'{col}_TE'] = TE.transform(x_val[col])
        x_test[f'{col}_TE'] = TE.transform(x_test[col])

      # random features

      x_train[randf] = "FE_"
      x_val[randf] = "FE_"
      x_test[randf] = "FE_"

      for col in randc:
          x_train[randf] += x_train[col].astype('str')
          x_val[randf] += x_val[col].astype('str')
          x_test[randf] += x_test[col].astype('str')

      TE.fit(x_train[randf], y_train)
      x_train[f'{randf}_TE'] = TE.transform(x_train[randf])
      x_val[f'{randf}_TE'] = TE.transform(x_val[randf])
      x_test[f'{randf}_TE'] = TE.transform(x_test[randf])

      for col in features:
          TE.fit(x_train[col], y_train)
          x_train[f'{col}_TE'] = TE.transform(x_train[col])
          x_val[f'{col}_TE'] = TE.transform(x_val[col])
          x_test[f'{col}_TE'] = TE.transform(x_test[col])


      x_train["colorxweight"] = x_train['Color_TE']*x_train['Weight Capacity (kg)_TE']
      x_val["colorxweight"] = x_val['Color_TE']*x_val['Weight Capacity (kg)_TE']
      x_test["colorxweight"] = x_test['Color_TE']*x_test['Weight Capacity (kg)_TE']

      x_train["Sizexweight"] = x_train['Size_TE']*x_train['Weight Capacity (kg)_TE']
      x_val["Sizexweight"] = x_val['Size_TE']*x_val['Weight Capacity (kg)_TE']
      x_test["Sizexweight"] = x_test['Size_TE']*x_test['Weight Capacity (kg)_TE']

      x_train["Sizexbrand"] = x_train['Size_TE']*x_train['Brand_TE']
      x_val["Sizexbrand"] = x_val['Size_TE']*x_val['Brand_TE']
      x_test["Sizexbrand"] = x_test['Size_TE']*x_test['Brand_TE']

      x_train["Materialxweight"] = x_train['Material_TE']*x_train['Weight Capacity (kg)_TE']
      x_val["Materialxweight"] = x_val['Material_TE']*x_val['Weight Capacity (kg)_TE']
      x_test["Materialxweight"] = x_test['Material_TE']*x_test['Weight Capacity (kg)_TE']

      for cat in cats:
          x_train[cat] =  x_train[cat].fillna("MISSING")
          x_val[cat] = x_val[cat].fillna("MISSING")
          x_test[cat] = x_test[cat].fillna("MISSING")
          x_train[cat] =  x_train[cat].astype('str')
          x_val[cat] = x_val[cat].astype('str')
          x_test[cat] = x_test[cat].astype('str')

      model = CatBoostRegressor(task_type = "GPU",
                                grow_policy = 'Lossguide',
                                random_state = 42,
                                cat_features = cats,
                                verbose = 250,
                                loss_function='RMSE')

      model.fit(x_train, y_train)

      val_preds = model.predict(x_val)

      oof[test_idx] = val_preds

      preds += model.predict(x_test)/config.n_splits

      score = rmse(y_val, val_preds)

      m.append(score)

      print(f'Fold: {fold+1}, Score: {score}')

  print(f"The average CV is {np.average(m)}, with {randf}")
  cats.pop()

  save_columns[randf] = randc
  save_score[randf] = np.average(m)
# Out:
# Trial 1: ['Material', 'Weight Capacity (kg)', 'Laptop Compartment', 'Compartments']
# Learning rate set to 0.116254
# 0:	learn: 38.8946597	total: 188ms	remaining: 3m 8s
# 250:	learn: 38.6395120	total: 15.3s	remaining: 45.7s
# 500:	learn: 38.6060853	total: 28.8s	remaining: 28.7s
# 750:	learn: 38.5768664	total: 40.4s	remaining: 13.4s
# 999:	learn: 38.5492775	total: 50.7s	remaining: 0us
# Fold: 1, Score: 38.65427185481561
# Learning rate set to 0.116254
# 0:	learn: 38.8964372	total: 71.9ms	remaining: 1m 11s
# 250:	learn: 38.6412370	total: 14.4s	remaining: 43.1s
# 500:	learn: 38.6094780	total: 23.7s	remaining: 23.6s
# 750:	learn: 38.5806687	total: 40.9s	remaining: 13.6s
# 999:	learn: 38.5537849	total: 54.1s	remaining: 0us
# Fold: 2, Score: 38.64430964195513
# Learning rate set to 0.116254
# 0:	learn: 38.8794639	total: 204ms	remaining: 3m 23s
# 250:	learn: 38.6244523	total: 12.8s	remaining: 38.3s
# 500:	learn: 38.5909876	total: 26.1s	remaining: 26s
# 750:	learn: 38.5630578	total: 39.5s	remaining: 13.1s
# 999:	learn: 38.5368519	total: 52.8s	remaining: 0us
# Fold: 3, Score: 38.71179081530723
# Learning rate set to 0.116254
# 0:	learn: 38.8934239	total: 71.1ms	remaining: 1m 11s
# 250:	learn: 38.6380069	total: 14.3s	remaining: 42.7s
# Fold: 5, Score: 38.69820587726024
# The average CV is 38.67309166169643, with Material-Size-Color
# Trial 9: ['Weight Capacity (kg)', 'Color']
# Learning rate set to 0.116254
# 0:	learn: 38.8946597	total: 73.7ms	remaining: 1m 13s
# 250:	learn: 38.6379570	total: 14.2s	remaining: 42.4s
# 500:	learn: 38.6052428	total: 25.2s	remaining: 25.1s
# 750:	learn: 38.5754188	total: 36.8s	remaining: 12.2s
# 999:	learn: 38.5489949	total: 49.4s	remaining: 0us
# Fold: 1, Score: 38.65124733871759
# Learning rate set to 0.116254
# 0:	learn: 38.8964372	total: 71.4ms	remaining: 1m 11s
# 250:	learn: 38.6386951	total: 16.6s	remaining: 49.5s
# 500:	learn: 38.6052988	total: 28.7s	remaining: 28.5s
# 750:	learn: 38.5776576	total: 38.3s	remaining: 12.7s
# 999:	learn: 38.5508257	total: 51.4s	remaining: 0us
# Fold: 2, Score: 38.64323134513508
# Learning rate set to 0.116254
# 0:	learn: 38.8795010	total: 72.6ms	remaining: 1m 12s
# 250:	learn: 38.6213700	total: 14.5s	remaining: 43.1s
# 500:	learn: 38.5875144	total: 27.8s	remaining: 27.7s
# 750:	learn: 38.5594345	total: 40.8s	remaining: 13.5s
# 999:	learn: 38.5318914	total: 50.2s	remaining: 0us
# Fold: 3, Score: 38.709039351604716
# Learning rate set to 0.116254
# 0:	learn: 38.8934775	total: 88.5ms	remaining: 1m 28s
# 250:	learn: 38.6353715	total: 14.2s	remaining: 42.5s
# 500:	learn: 38.6031843	total: 27.1s	remaining: 27s
# 750:	learn: 38.5751927	total: 40.3s	remaining: 13.4s
# 999:	learn: 38.5483009	total: 49.5s	remaining: 0us
# Fold: 4, Score: 38.65735725165731
# Learning rate set to 0.116254
# 0:	learn: 38.8804881	total: 70.4ms	remaining: 1m 10s
# 250:	learn: 38.6239111	total: 14.4s	remaining: 42.8s
# 500:	learn: 38.5912805	total: 27.6s	remaining: 27.5s
# 750:	learn: 38.5637394	total: 40.8s	remaining: 13.5s
# 999:	learn: 38.5374612	total: 51.2s	remaining: 0us
# Fold: 5, Score: 38.69800935638764
# The average CV is 38.67177692870047, with Weight Capacity (kg)-Color
# Trial 10: ['Brand', 'Color', 'Waterproof']
# Learning rate set to 0.116254
# 0:	learn: 38.8943590	total: 77.3ms	remaining: 1m 17s
# 250:	learn: 38.6420497	total: 14.5s	remaining: 43.2s
# 500:	learn: 38.6093826	total: 31.2s	remaining: 31.1s
# 750:	learn: 38.5810507	total: 41.4s	remaining: 13.7s
# 999:	learn: 38.5544997	total: 54s	remaining: 0us
# Fold: 1, Score: 38.65285719682866
# Learning rate set to 0.116254
# 0:	learn: 38.8961860	total: 87.2ms	remaining: 1m 27s
# 250:	learn: 38.6426531	total: 11s	remaining: 32.9s
# 500:	learn: 38.6111484	total: 23.9s	remaining: 23.8s
# 750:	learn: 38.5826372	total: 37.2s	remaining: 12.3s
# 999:	learn: 38.5559812	total: 50.5s	remaining: 0us
# Fold: 2, Score: 38.645395930136054
# Learning rate set to 0.116254
# 0:	learn: 38.8793382	total: 71.8ms	remaining: 1m 11s
# 250:	learn: 38.6267836	total: 14.4s	remaining: 42.9s
# 500:	learn: 38.5946765	total: 27.9s	remaining: 27.8s
# 750:	learn: 38.5671253	total: 41.3s	remaining: 13.7s
# 999:	learn: 38.5400429	total: 51.7s	remaining: 0us
# Fold: 3, Score: 38.70985850387329
# Learning rate set to 0.116254
# 0:	learn: 38.8932179	total: 73.4ms	remaining: 1m 13s
# 250:	learn: 38.6400140	total: 17.5s	remaining: 52.2s
# 500:	learn: 38.6082249	total: 30.6s	remaining: 30.5s
# 750:	learn: 38.5809990	total: 40.2s	remaining: 13.3s
# 999:	learn: 38.5547867	total: 53.2s	remaining: 0us
# Fold: 4, Score: 38.658586946767116
# Learning rate set to 0.116254
# 0:	learn: 38.8803995	total: 198ms	remaining: 3m 18s
# 250:	learn: 38.6284596	total: 11.4s	remaining: 34s
# 500:	learn: 38.5973024	total: 24.7s	remaining: 24.6s
# 750:	learn: 38.5698071	total: 38s	remaining: 12.6s
# 999:	learn: 38.5440278	total: 51.4s	remaining: 0us
# Fold: 5, Score: 38.698760914332865
# The average CV is 38.6730918983876, with Brand-Color-Waterproof

# %%
save_score
# Out:
# {'Material-Weight Capacity (kg)-Laptop Compartment-Compartments': 38.67345796317473,
#  'Weight Capacity (kg)-Material-Brand-Compartments': 38.67295645037395,
#  'Size-Laptop Compartment': 38.67222711894046,
#  'Weight Capacity (kg)-Color-Material-Style': 38.67282450133342,
#  'Brand-Weight Capacity (kg)-Compartments-Color': 38.67332641740568,
#  'Brand-Laptop Compartment-Waterproof': 38.672719364801125,
#  'Material-Color-Style': 38.67294412525279,
#  'Material-Size-Color': 38.67309166169643,
#  'Weight Capacity (kg)-Color': 38.67177692870047,
#  'Brand-Color-Waterproof': 38.6730918983876}

# %%
# plot the scores
keys = list(save_score.keys())
values = list(save_score.values())

plt.figure(figsize=(25, 6))
plt.xticks(rotation=90)
plt.axhline(y= 38.67177692870047)
sns.scatterplot(x = keys, y =values)
# Out:
# <Axes: >

# %%
submission = pd.read_csv(config.sub_link)
submission[config.target] = preds
submission.to_csv("submission.csv", index = False)

submission
# Out:
#             id      Price
# 0       300000  81.462612
# 1       300001  82.910101
# 2       300002  88.752305
# 3       300003  78.625491
# 4       300004  79.290319
# ...        ...        ...
# 199995  499995  81.695077
# 199996  499996  72.627944
# 199997  499997  83.150996
# 199998  499998  82.150532
# 199999  499999  81.956200
#
# [200000 rows x 2 columns]

# %%
drop = ['Brand', 'Material', 'Size', 'Compartments', 'Laptop Compartment', 'Color', 'Waterproof']

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x=model.get_feature_importance(), y=x_train.columns)
plt.title('Feature Importance')
plt.xlabel('Importance')
plt.ylabel('Features')
plt.show()

# %%
if config.submit:
  # !kaggle competitions submit -c {competition} -f submission.csv -m 'Submission with 20 kfold TE combo'
# Out:
# 100% 4.74M/4.74M [00:01<00:00, 4.00MB/s]
# Successfully submitted to Backpack Prediction Challenge

# %%
# !kaggle competitions submissions -c {competition}
# Out:
# fileName        date                 description                                         status    publicScore  privateScore
# --------------  -------------------  --------------------------------------------------  --------  -----------  ------------
# submission.csv  2025-02-08 00:45:22  Submission with 20 kfold TE combo                   pending
# submission.csv  2025-02-08 00:06:03  Submission with 20 kfold TE combo                   complete  38.85639
# submission.csv  2025-02-07 05:46:15  Notebook 10 folds Backpack Prediction  | Version 2  complete  38.85514
# submission.csv  2025-02-07 04:56:39  Notebook 10 folds Backpack Prediction  | Version 1  complete  38.85598
# submission.csv  2025-02-07 04:27:10  Notebook Fork of Backpack Prediction  | Version 5   complete  38.85840
# submission.csv  2025-02-07 04:10:02  Notebook Fork of Backpack Prediction  | Version 4   complete  38.85656
# submission.csv  2025-02-07 03:41:16  Notebook Fork of Backpack Prediction  | Version 3   complete  38.85793
# submission.csv  2025-02-06 10:33:56  Notebook Fork of Backpack Prediction  | Version 2   complete  38.85709
# submission.csv  2025-02-06 10:24:43  Notebook Fork of Backpack Prediction  | Version 1   complete  38.85873
# submission.csv  2025-02-05 12:13:58  Notebook Backpack Prediction | Ridge  | Version 18  complete  38.91498
# submission.csv  2025-02-05 10:39:06  Notebook Backpack Prediction | Ridge  | Version 17  complete  38.88895
# submission.csv  2025-02-05 10:15:41  Notebook Backpack Prediction  | Version 16          complete  38.85931
# submission.csv  2025-02-05 09:59:22  Notebook Backpack Prediction  | Version 15          complete  38.85777
# submission.csv  2025-02-05 08:52:48  Notebook Backpack Prediction  | Version 14          complete  38.85842
# submission.csv  2025-02-04 10:43:15  Notebook Backpack Prediction  | Version 13          complete  38.96142
# submission.csv  2025-02-04 10:06:53  Notebook Backpack Prediction  | Version 12          complete  38.91028
# submission.csv  2025-02-04 09:39:41  Notebook Backpack Prediction  | Version 11          complete  38.91149
# submission.csv  2025-02-04 09:24:18  Notebook Backpack Prediction  | Version 10          complete  38.91159
# submission.csv  2025-02-04 09:14:27  Notebook Backpack Prediction  | Version 9           complete  39.16450
# submission.csv  2025-02-03 11:28:36  Notebook Backpack Prediction  | Version 8           complete  39.15617
# submission.csv  2025-02-03 11:22:12  Notebook Backpack Prediction  | Version 7           complete  39.17115
# submission.csv  2025-02-03 10:45:41  Notebook Backpack Prediction  | Version 6           complete  39.16361
# submission.csv  2025-02-03 10:43:56  Notebook Backpack Prediction  | Version 5           complete  40.43406
# submission.csv  2025-02-03 10:42:37  Notebook Backpack Prediction  | Version 4           complete  55.06271
# submission.csv  2025-02-02 03:26:32  Notebook Backpack Prediction  | Version 3           complete  39.16483
# submission.csv  2025-02-02 03:24:32  Notebook Backpack Prediction  | Version 2           complete  39.18728
# submission.csv  2025-02-02 03:22:54  Notebook Backpack Prediction  | Version 1           complete  39.17011
# submission.csv  2025-02-02 03:18:24                                                      complete  39.12145
# submission.csv  2025-02-01 09:32:57                                                      complete  39.11685
# submission.csv  2025-02-01 09:24:52                                                      complete  39.11964
# submission.csv  2025-02-01 09:04:33                                                      complete  39.11965
# submission.csv  2025-02-01 08:20:14                                                      complete  39.11774
# submission.csv  2025-02-01 06:50:24                                                      complete  39.13171
# submission.csv  2025-02-01 06:46:36                                                      error
